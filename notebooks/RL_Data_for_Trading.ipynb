# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploads=files.upload()
# Out:
#      <input type="file" id="files-686bf781-1d54-4c3b-aed3-34d8564be8f0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-686bf781-1d54-4c3b-aed3-34d8564be8f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving training.csv to training (1).csv

# %%
data = pd.read_csv('training.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  228 non-null    int64
#  1   close       228 non-null    float64
#  2   SMA         228 non-null    float64
#  3   MACD        228 non-null    float64
#  4   SIGNAL      228 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 9.0 KB

# %%
data.head(10)
# Out:
#    Unnamed: 0   close       SMA      MACD    SIGNAL
# 0           0  1.5670  1.575671 -0.013281 -0.012706
# 1           1  1.5517  1.572371 -0.014337 -0.013032
# 2           2  1.5472  1.568914 -0.015360 -0.013498
# 3           3  1.5479  1.565393 -0.015930 -0.013984
# 4           4  1.5421  1.562079 -0.016658 -0.014519
# 5           5  1.5404  1.559557 -0.017174 -0.015050
# 6           6  1.5262  1.556871 -0.018516 -0.015743
# 7           7  1.5232  1.554386 -0.019595 -0.016514
# 8           8  1.4988  1.549186 -0.022164 -0.017644
# 9           9  1.4970  1.544729 -0.024068 -0.018928

# %%
data_copy = data.copy()
df = data_copy.drop(['Unnamed: 0'], axis=1)

# %%
df.describe()
# Out:
#             close         SMA        MACD      SIGNAL
# count  228.000000  228.000000  228.000000  228.000000
# mean     1.537372    1.538075   -0.001119   -0.001174
# std      0.044309    0.042224    0.011617    0.011009
# min      1.428200    1.446971   -0.024710   -0.022535
# 25%      1.509450    1.509750   -0.010320   -0.009439
# 50%      1.542250    1.544543    0.000769    0.000252
# 75%      1.571000    1.571664    0.008260    0.007454
# max      1.626900    1.607186    0.023306    0.020761

# %%
def plt_corr(df, size = 10):
  corr = df.corr()
  fig, ax = plt.subplots(figsize =(size, size))
  ax.matshow(corr)
  plt.xticks(range(len(corr.columns)), corr.columns)
  plt.yticks(range(len(corr.columns)), corr.columns)

  plt.setp(ax.get_xticklabels(), rotation=90, horizontalalignment='right')

# %%
plt_corr(df)

# %% [markdown]
# By default, this function will create a grid of Axes such that each numeric variable in data will by shared across the y-axes across a single row and the x-axes across a single column. The diagonal plots are treated differently: a univariate distribution plot is drawn to show the marginal distribution of the data in each column.

# %%
sns.pairplot(df, diag_kind='kde')
